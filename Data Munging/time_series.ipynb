# %%
'''
A measure of unit change over time for any variable under observation
Useful and predicting and forecasting from historical data
Frequently used models: ARMA,ARIMA(Box-Jenkins)
'''
# Out:
# '\nA measure of unit change over time for any variable under observation\nUseful and predicting and forecasting from historical data\nFrequently used models: ARMA,ARIMA(Box-Jenkins)\n'

# %%
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sb
from IPython.display import Image,display

import matplotlib.image as mpimg
rcParams['figure.figsize'] = 20,8

image = mpimg.imread('D:\Workspace\Data Munging\info.png')
implot =  plt.imshow(image)
plt.show()

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5,4
sb.set_style('whitegrid')

# %%
path = "D:\Workspace\Data Munging\Superstore.xlsx"
store_data = pd.read_excel(path,index_col='Order Date',parse_dates=True)
print(store_data.head())
# Out:
#             Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# Order Date
# 2012-05-28   18606  Not Specified      0.01        2.88           0.50
# 2010-07-07   20847           High      0.01        2.84           0.93
# 2011-07-27   23086  Not Specified      0.03        6.68           6.15
# 2011-07-27   23087  Not Specified      0.01        5.68           3.60
# 2011-07-27   23088  Not Specified      0.00      205.99           2.50
#
#             Customer ID    Customer Name    Ship Mode Customer Segment  \
# Order Date
# 2012-05-28            2  Janice Fletcher  Regular Air        Corporate
# 2010-07-07            3    Bonnie Potter  Express Air        Corporate
# 2011-07-27            3    Bonnie Potter  Express Air        Corporate
# 2011-07-27            3    Bonnie Potter  Regular Air        Corporate
# 2011-07-27            3    Bonnie Potter  Express Air        Corporate
#
#            Product Category    ...    Product Base Margin   Region  \
# ...

# %%
store_data['Product Base Margin'].plot()

# %%
df2 = store_data.sample(n=100,random_state=25,axis=0)
plt.xlabel('Order Date')
plt.ylabel('Product Base Margin')
plt.title('Super store sales')

df2['Product Base Margin'].plot()
